# %% [markdown]
# # FX Leverage Carry-Trade

# %%
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import carry_trade as ct

matplotlib.rcParams[ 'figure.figsize' ] = ( 16, 9 )

# %% [markdown]
# ## 1. Load data

# %%
FX_IR_FR = pd.read_pickle('FX_IR_FR.csv')

# %%
# Sort values by day with ascending order 
FX_IR_FR = FX_IR_FR.sort_values(by='Date', ascending=True)

# Set date as index
FX_IR_FR = FX_IR_FR.set_index('Date')

# %%
FX_IR_FR.tail()
# Out:
#            Currency  SpotRate       1MF       2MF       3MF       6MF  \
# Date
# 2019-10-25  USD/JPY    108.65  108.4547  108.2672  107.9873  107.4149
# 2019-10-29  USD/JPY    108.91  108.7243  108.5337  108.2351  107.6667
# 2019-10-30  USD/JPY    108.84  108.6449  108.3333  108.1599  107.6053
# 2019-10-31  USD/JPY    108.20  108.0149  107.7240  107.5352  106.9628
# 2019-11-01  USD/JPY    108.00  107.8190  107.5401  107.3500  106.7902
#
#                 12MF    1MUSD    2MUSD    3MUSD  ...    2MJPY    3MJPY  \
# Date                                             ...
# 2019-10-25  106.3300  1.80488  1.88100  1.92813  ... -0.09067 -0.11000
# 2019-10-29  106.5432  1.78588  1.86313  1.92713  ... -0.07717 -0.11667
# 2019-10-30  106.4773  1.78138  1.85900  1.90913  ... -0.09750 -0.11683
# 2019-10-31  105.8764  1.78488  1.84000  1.90225  ... -0.10317 -0.11500
# 2019-11-01  105.7187  1.77425  1.83888  1.89050  ... -0.10350 -0.11583
#
#               6MJPY   12MJPY   SpotDate      1MFR      2MFR      3MFR  \
# Date
# 2019-10-25 -0.04750  0.03883 2019-10-30  108.4547  108.2672  107.9873
# 2019-10-29 -0.03533  0.05533 2019-10-31  108.7243  108.5337  108.2351
# 2019-10-30 -0.04200  0.05000 2019-11-01  108.6449  108.3333  108.1599
# 2019-10-31 -0.04750  0.04383 2019-11-04  108.0149  107.7240  107.5352
# 2019-11-01 -0.04217  0.03800 2019-11-05  107.8190  107.5401  107.3500
#
#                 6MFR     12MFR
# Date
# 2019-10-25  107.4149  106.3300
# 2019-10-29  107.6667  106.5432
# 2019-10-30  107.6053  106.4773
# 2019-10-31  106.9628  105.8764
# 2019-11-01  106.7902  105.7187
#
# [5 rows x 23 columns]
#            Currency  SpotRate       1MF       2MF       3MF       6MF  \
# Date
# 2019-10-25  USD/JPY    108.65  108.4547  108.2672  107.9873  107.4149
# 2019-10-29  USD/JPY    108.91  108.7243  108.5337  108.2351  107.6667
# 2019-10-30  USD/JPY    108.84  108.6449  108.3333  108.1599  107.6053
# 2019-10-31  USD/JPY    108.20  108.0149  107.7240  107.5352  106.9628
# 2019-11-01  USD/JPY    108.00  107.8190  107.5401  107.3500  106.7902
#
#                 12MF    1MUSD    2MUSD    3MUSD  ...    2MJPY    3MJPY  \
# Date                                             ...
# 2019-10-25  106.3300  1.80488  1.88100  1.92813  ... -0.09067 -0.11000
# 2019-10-29  106.5432  1.78588  1.86313  1.92713  ... -0.07717 -0.11667
# 2019-10-30  106.4773  1.78138  1.85900  1.90913  ... -0.09750 -0.11683
# 2019-10-31  105.8764  1.78488  1.84000  1.90225  ... -0.10317 -0.11500
# 2019-11-01  105.7187  1.77425  1.83888  1.89050  ... -0.10350 -0.11583
#
#               6MJPY   12MJPY   SpotDate      1MFR      2MFR      3MFR  \
# Date
# 2019-10-25 -0.04750  0.03883 2019-10-30  108.4547  108.2672  107.9873
# 2019-10-29 -0.03533  0.05533 2019-10-31  108.7243  108.5337  108.2351
# 2019-10-30 -0.04200  0.05000 2019-11-01  108.6449  108.3333  108.1599
# 2019-10-31 -0.04750  0.04383 2019-11-04  108.0149  107.7240  107.5352
# 2019-11-01 -0.04217  0.03800 2019-11-05  107.8190  107.5401  107.3500
#
#                 6MFR     12MFR
# Date
# 2019-10-25  107.4149  106.3300
# 2019-10-29  107.6667  106.5432
# 2019-10-30  107.6053  106.4773
# 2019-10-31  106.9628  105.8764
# 2019-11-01  106.7902  105.7187
#
# [5 rows x 23 columns]

# %% [markdown]
# ## 2. Implement Strategy

# %%
results_1m = ct.algo_loop( FX_IR_FR )
# Out:
# 2019-11-09 18:03:22:930465: Beginning Carry-Trade Strategy run
# 2019-11-09 18:03:22:930465: Beginning Carry-Trade Strategy run
# 2019-11-09 18:03:25:982092: Algo run complete.
# 2019-11-09 18:03:25:982092: Algo run complete.

# %%
results_1m.to_csv('results_1m.csv')

# %%
results_1m

# ps: the amount of euity we invest doesn't affect the PnL(%)
# Out:
#                  Signal  USD_IR(%)  JPY_IR(%) FX_Rate Equity Asset Pos  \
# Date
# 2009-10-01 -0.000126903  0.0024563    0.00175   89.93  10000    -20000
# 2009-10-05 -0.000108263  0.0024438  0.0017125   89.86  10000    -20000
# 2009-10-06 -0.000125344  0.0024438  0.0017125   89.14  10000    -20000
# 2009-10-07 -0.000134804  0.0024438  0.0017125  88.921  10000    -20000
# 2009-10-08  -0.00012834  0.0024438     0.0017    88.3  10000    -20000
# ...                 ...        ...        ...     ...    ...       ...
# 2019-10-25 -0.000209028  0.0180488   -0.00105  108.65  10000    -20000
# 2019-10-29 -0.000123484  0.0178588 -0.0011533  108.91  10000    -20000
# 2019-10-30 -0.000216939  0.0178138   -0.00113  108.84  10000    -20000
# 2019-10-31 -0.000133035  0.0178488 -0.0011167   108.2  10000    -20000
# 2019-11-01 -0.000106148  0.0177425 -0.0011267     108  10000    -20000
#
#              Unreal_PnL  Real_PnL
# Date
# 2009-10-01    0.0010437         0
# 2009-10-05 -0.000515791         0
# 2009-10-06   -0.0165563         0
# 2009-10-07   -0.0214352         0
# 2009-10-08   -0.0352702         0
# ...                 ...       ...
# 2019-10-25   -0.0128837 -0.278595
# 2019-10-29  -0.00808328 -0.278595
# 2019-10-30   -0.0093757 -0.278595
# 2019-10-31   -0.0211921 -0.278595
# 2019-11-01   -0.0248848 -0.278595
#
# [2523 rows x 8 columns]
#                  Signal  USD_IR(%)  JPY_IR(%) FX_Rate Equity Asset Pos  \
# Date
# 2009-10-01 -0.000126903  0.0024563    0.00175   89.93  10000    -20000
# 2009-10-05 -0.000108263  0.0024438  0.0017125   89.86  10000    -20000
# 2009-10-06 -0.000125344  0.0024438  0.0017125   89.14  10000    -20000
# 2009-10-07 -0.000134804  0.0024438  0.0017125  88.921  10000    -20000
# 2009-10-08  -0.00012834  0.0024438     0.0017    88.3  10000    -20000
# ...                 ...        ...        ...     ...    ...       ...
# 2019-10-25 -0.000209028  0.0180488   -0.00105  108.65  10000    -20000
# 2019-10-29 -0.000123484  0.0178588 -0.0011533  108.91  10000    -20000
# 2019-10-30 -0.000216939  0.0178138   -0.00113  108.84  10000    -20000
# 2019-10-31 -0.000133035  0.0178488 -0.0011167   108.2  10000    -20000
# 2019-11-01 -0.000106148  0.0177425 -0.0011267     108  10000    -20000
#
#              Unreal_PnL  Real_PnL
# Date
# 2009-10-01    0.0010437         0
# 2009-10-05 -0.000515791         0
# 2009-10-06   -0.0165563         0
# 2009-10-07   -0.0214352         0
# 2009-10-08   -0.0352702         0
# ...                 ...       ...
# 2019-10-25   -0.0128837 -0.278595
# 2019-10-29  -0.00808328 -0.278595
# 2019-10-30   -0.0093757 -0.278595
# 2019-10-31   -0.0211921 -0.278595
# 2019-11-01   -0.0248848 -0.278595
#
# [2523 rows x 8 columns]

# %% [markdown]
# ## 3. Analysis

# %%
fig = plt.figure(figsize=(20,5))
ax1 = fig.add_subplot(211)
ax1.grid(False)

ax1.plot(FX_IR_FR.index, FX_IR_FR['1MUSD'], label='1MUSD')
ax1.plot(FX_IR_FR.index, FX_IR_FR['1MJPY'], label='1MUSD')

ax1.legend(loc = 'upper left')
ax1.set_ylabel('Pct(%)')

ax2 = ax1.twinx()
ax2.grid(True)

ax2.plot(results_1m.index, results_1m['Real_PnL(%)'], color='yellowgreen', label='Realized P&L')

ax2.legend(loc = 'lower left')
ax2.set_ylabel('Pct(%)')


plt.show()
